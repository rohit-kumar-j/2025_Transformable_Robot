# %% [markdown]
# https://www.wemos.cc/en/latest/s2/s2_mini.html
# ![image.png](attachment:2c9651c8-8e59-4ec9-9173-df353e9e22db.png)

# %% [markdown]
# # !!重要！！
# # 必要步骤
# # motor sheild v1 需要重新刷写
#
# https://espeasy.readthedocs.io/en/latest/Plugin/P079_WemosMotorshield.html

# %% [markdown]
# https://www.wemos.cc/en/latest/d1_mini_shield/matrix_led.html

# %% [markdown]
# ![image.png](attachment:33b0dc8f-5136-423f-8b18-a89f9e7339b4.png)

# %% [markdown]
# ![image.png](attachment:cd30c45f-b78f-4f40-9b02-6313bd288a25.png)
